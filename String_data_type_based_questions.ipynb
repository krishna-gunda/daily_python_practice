# %% [markdown]
# <a href="https://colab.research.google.com/github/krishna-gunda/daily_python_practice/blob/main/String_data_type_based_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="airtificial intelligence".upper()
a
# Out:
# 'AIRTIFICIAL INTELLIGENCE'

# %% [markdown]
# Capitalize the first letter of a sentence.

# %%
print("apple".title())
# Out:
# Apple

# %% [markdown]
# Convert every word's first letter to uppercase.

# %%
print("krishna is a good boy".title())
# Out:
# Krishna Is A Good Boy

# %% [markdown]
# Check whether a string starts with a given word.

# %%
print("krishna".startswith("k"))
# Out:
# True

# %%
def startwith(str,prefix):
  a=0
  for i in range((len(prefix))):
    if str[i]==prefix[i]:
      a=a+1
    else:
      a
  if a== len(prefix):
    return True
  else:
    return False

# %%
startwith("krishna","ksh")
# Out:
# False

# %% [markdown]
# Count how many times a character appears.

# %%
def count(str,chr):
  return str.count(chr)

# %%
count("krishna","k")
# Out:
# 1

# %% [markdown]
# Replace all spaces with underscores.

# %%
"virat kohili krishna".replace(" ","_")
# Out:
# 'virat_kohili_krishna'

# %%
a="krishna is a good boy"
print("bad" in a)
# Out:
# False

# %%
a="k"
result=ord(a)
print(result)
# Out:
# 107

# %% [markdown]
# Replace all spaces with underscores.

# %%
"The AI is defined as Airtificial Intellegence".replace(" ","_")
# Out:
# 'The_AI_is_defined_as_Airtificial_Intellegence'

# %% [markdown]
# Split a sentence into words.

# %%
"The AI is defined as Airtificial Intellegence".split(" ")
# Out:
# ['The', 'AI', 'is', 'defined', 'as', 'Airtificial', 'Intellegence']

# %% [markdown]
# Join a list of words into a sentence.

# %%
a=['The', 'AI', 'is', 'defined', 'as', 'Airtificial', 'Intellegence']
" ".join(a)
# Out:
# 'The AI is defined as Airtificial Intellegence'

# %% [markdown]
# Check whether a string contains only letters and numbers.

# %%
a="The AI is defined as Airtificial Intellegence"  # the spaces are not treated as alphabets
a.isalpha()
# Out:
# False

# %%
"Airtificial".isalpha()
# Out:
# True

# %%
a.index("t",25)   #   string.index(value, start, end) start with the 25 until the last
# Out:
# 35
